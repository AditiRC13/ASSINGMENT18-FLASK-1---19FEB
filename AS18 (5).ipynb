# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
# Flask -Flask is a web framework, it’s a Python module that lets you develop web applications easily.
#
# Flask Framework- Flask is a web framework. This means flask provides you with tools, libraries and technologies that allow you to build a web application. This web application can be some web pages, a blog, a wiki or go as big as a web-based calendar application or a commercial website.
#
# Advantage of Flask-
# 1.The Flask framework is easy to understand, that is why it is best for beginners.
# 2.Using Flask for web development allows for unit testing through its integrated support, built-in               development server, fast debugger, and restful request dispatching.
# 3.It is lightweight to enable you to transit into a web framework easily with some extension.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ![PIC1.png](attachment:6eb622ec-f309-40ed-90c6-9c70227211f5.png)

# %% [markdown]
# ![PIC 2.png](attachment:eed52055-9651-4c20-9578-4d7bbeceb487.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
# App Routing means mapping the URLs to a specific function that will handle the logic for that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make navigation simpler.
#
# On the top of the function we want to map, wll add @app.route("</path>"). In above example /(root) is mapped to hello_word function.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# ![img 0.png](attachment:351697b9-78ad-45bb-9d7a-df0b6070de3c.png)

# %% [markdown]
# ![img2.png](attachment:6b65bd81-4b01-4517-9276-738f0969353d.png)

# %% [markdown]
# ![img 1.png](attachment:d2e005c6-bff3-4b15-a676-09fdefcdc782.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.
#
# The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.
#
# from flask import *
#
# app = Flask(name)
#
# @app.route("/")
# def company():
#     data = '''
#     <a href="{{ url_for('welcome') }}"> Welcome Page </a>
#     <p>Name: ABC Corporation <br>
#     Location: India <br>
#     Contact Detail: 999-999-9999<br><p>
#     '''
#     return data
#
#
# @app.route('/home')
# def home():
#     return redirect(url_for('company'))
#
# if name=="main":
#     app.run(host="0.0.0.0")
